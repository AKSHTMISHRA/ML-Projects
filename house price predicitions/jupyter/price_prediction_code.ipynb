# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as mp

# %%
train_file=pd.read_csv("train.csv")

# %%
train_file.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train_file.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_file.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
#checking all the columns having null values
train_file_null_columns=train_file[train_file.columns[train_file.isna().any()]]

# %%
#created a dataframe containing all the columns having NULL values
train_file_null=pd.DataFrame(train_file_null_columns)
train_file_null.head()

print("=" * 80,"\n")
print("Total Null values")
print("-" * 80,"\n")
print(train_file_null.isnull().sum())

print("=" * 80,"\n")
print("Columns Containing Null values")
print("-" * 80,"\n")
print("All the null columns \n",train_file_null.columns,'\n')
print("-" * 80,"\n")
print("All the columns \n",train_file.columns,'\n')
print("-" * 80,"\n")
print("total no of columns\n",len(train_file.columns))
print("-" * 80,"\n")
print("total no of columns with null values\n",len(train_file_null.columns))
# Out:
# ...
#
# Total Null values
# --------------------------------------------------------------------------------
#
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64
# ...
#
# Columns Containing Null values
# --------------------------------------------------------------------------------
#
# All the null columns
#  Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
# ...

# %%
# checking correlation between All the features
mp.figure(figsize=(12, 10))  # Adjust the size of the heatmap as needed
sb.heatmap(train_file.corr(), cmap='coolwarm', fmt=".2f")#annot=True,
mp.title("Correlation Heatmap")
mp.show()

# %%
# checking correlation between salesprice and All the other features
SalePrice_corr=train_file.corr()['SalePrice']
mp.figure(figsize=(12, 10))  # Adjust the size of the heatmap as needed
sb.heatmap(SalePrice_corr.to_frame(),cmap='coolwarm', fmt='.2f')#annot=True,
mp.title("Correlation Heatmap")
mp.show()

# %% [markdown]
# From the above graph we could see some features need "label encoding",

# %%
#finding all the  features for labeel encoding
all_features = train_file.columns.tolist()

# Get the features that are not present in the correlation calculation
missing_features = [feature for feature in all_features if feature not in SalePrice_corr.index]

# Print or use the missing_features list as needed
print("Features which needs label encoding")
print("-"*80)
print(missing_features)
# Out:
# Features which needs label encoding
# --------------------------------------------------------------------------------
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
#label encoding 
from sklearn.preprocessing import LabelEncoder
data = train_file[['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']].copy()

# Apply label encoding to each feature in the 'data' DataFrame
label_encoder = LabelEncoder()

#applying the encoded features
# for feature in data:
#     train_file[feature] = label_encoder.fit_transform(train_file[feature])

# another method
data = data.apply(label_encoder.fit_transform)

# Replace the original columns in 'train_file' with the encoded values
train_file[['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 
           'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 
           'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 
           'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 
           'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
           'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu',
           'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 
           'SaleType', 'SaleCondition']] = data

# %%
#viewing encoded data 
train_file.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         3         65.0     8450       1      2         3
# 1   2          20         3         80.0     9600       1      2         3
# 2   3          60         3         68.0    11250       1      2         0
# 3   4          70         3         60.0     9550       1      2         0
# 4   5          60         3         84.0    14260       1      2         0
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            3          0  ...         0       3      4            4        0
# 1            3          0  ...         0       3      4            4        0
# 2            3          0  ...         0       3      4            4        0
# 3            3          0  ...         0       3      4            4        0
# 4            3          0  ...         0       3      4            4        0
#
# ...

# %%
# creating correlation graph after label encoding
# checking correlation between salesprice and All the other features
SalePrice_corr=train_file.corr()['SalePrice']
mp.figure(figsize=(12, 50))  # Adjust the size of the heatmap as needed
sb.heatmap(SalePrice_corr.to_frame(),cmap='coolwarm', fmt='.2f',annot=True)
mp.title("Correlation Heatmap")
mp.show()

# %%
#finding all the features where correlation value > 0.5

def find_high_correlation_features(train_file, target_feature, threshold=0.5):
    # Calculate the correlation matrix
    corr_matrix = train_file.corr()
    
    # Filter features with correlation greater than the threshold
    high_corr_features = corr_matrix[abs(corr_matrix[target_feature]) > threshold][target_feature]
    
    # Remove the target feature itself from the list
    high_corr_features = high_corr_features.drop(target_feature)
    
    return high_corr_features.index.tolist()


high_corr_features_gt05 = find_high_correlation_features(train_file, 'SalePrice', threshold=0.5)

print("Features with correlation > 0.5 for SalesPrice:")
print(high_corr_features)
# Out:
# Features with correlation > 0.5 for SalesPrice:
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'ExterQual', 'BsmtQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'KitchenQual', 'TotRmsAbvGrd', 'GarageFinish', 'GarageCars', 'GarageArea']

# %%
#finding all the features where correlation value > 0.75

def find_high_correlation_feature(train_file, target_feature, threshold=0.75):
    # Calculate the correlation matrix
    corr_matrix = train_file.corr()
    
    # Filter features with correlation greater than the threshold
    high_corr_features = corr_matrix[abs(corr_matrix[target_feature]) > threshold][target_feature]
    
    # Remove the target feature itself from the list
    high_corr_features = high_corr_features.drop(target_feature)
    
    return high_corr_features.index.tolist()


high_corr_features_gt075 = find_high_correlation_feature(train_file, 'SalePrice', threshold=0.75)

print("Features with correlation > 0.75 for SalesPrice:")
print(high_corr_features)
# Out:
# Features with correlation > 0.75 for SalesPrice:
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'ExterQual', 'BsmtQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'KitchenQual', 'TotRmsAbvGrd', 'GarageFinish', 'GarageCars', 'GarageArea']

# %%
def find_high_correlation_features(train_file, target_feature, threshold=0.5):
    # Calculate the correlation matrix
    corr_matrix = train_file.corr()
    
    # Filter features with correlation greater than the threshold
    high_corr_features = corr_matrix[corr_matrix[target_feature] > threshold][target_feature]
    
    # Remove the target feature itself from the list
    high_corr_features = high_corr_features.drop(target_feature)
    
    # Get the correlation values for the selected features
    correlations = corr_matrix.loc[target_feature, high_corr_features.index]
    
    return high_corr_features.index.tolist(), correlations


high_corr_features, correlations = find_high_correlation_features(train_file, 'SalePrice', threshold=0.5)

print("Features with correlation value > 0.5 for SalesPrice:")
print("="*80,"\n")
for feature, correlation in zip(high_corr_features, correlations):
    print(f"{feature}: {correlation:.3f}")
# Out:
# Features with correlation value > 0.5 for SalesPrice:
# ...
#
# OverallQual: 0.791
# YearBuilt: 0.523
# YearRemodAdd: 0.507
# TotalBsmtSF: 0.614
# 1stFlrSF: 0.606
# GrLivArea: 0.709
# FullBath: 0.561
# TotRmsAbvGrd: 0.534
# GarageCars: 0.640
# GarageArea: 0.623

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Assuming you have loaded your dataset into a DataFrame named 'train_file'
# And 'high_corr_features' contains the list of highly correlated feature names

# Select the independent variables (features)
x = train_file[high_corr_features]

# Select the dependent variable (target feature)
y = train_file['SalePrice']

# Split the data into training and testing sets (adjust the test_size as needed)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create and train the Linear Regression model
model = LinearRegression()
model.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model.predict(x_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("R-squared (R2) score:", r2)
# Out:
# Mean Squared Error (MSE): 1558239575.151087
# R-squared (R2) score: 0.79684833042811
